# %%
with open('D:\\Coding journey 2024\\datascience\\smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        prices.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 1020

# %%
len(prices)
# Out:
# 1020

# %%
len(ratings)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings
})

# %%
df.isnull().sum()
# Out:
# model       0
# price       0
# rating    592
# dtype: int64

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                             model    price rating  \
# 0                      Vivo T3 5G  ₹19,999    NaN
# 1                Nothing Phone 2a  ₹23,999    NaN
# 2                        Poco C61   ₹6,999     66
# 3                      iQOO Z9 5G  ₹19,660    NaN
# 4     Xiaomi Redmi Note 13 Pro 5G  ₹23,878    NaN
# ...                           ...      ...    ...
# 1015                 Karbonn KX70   ₹1,145    NaN
# 1016                 GFive Z9 New     ₹664    NaN
# 1017                 GFive Z8 New     ₹664    NaN
# 1018             itel Ace 2 Heera     ₹857    NaN
# 1019               Karbonn ‎KX11I     ₹899    NaN
#
#                                                  sim  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 3                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# ...                                              ...
# 1015                                        Dual Sim
# 1016                                        Dual Sim
# 1017                                        Dual Sim
# 1018                                        Dual Sim
# 1019                                        Dual Sim
#
#                                               processor  \
# 0          Dimensity 7200, Octa Core, 2.8 GHz Processor
# 1      Dimensity 7200 Pro, Octa Core, 2.8 GHz Processor
# 2               Helio G36, Octa Core, 2.2 GHz Processor
# 3          Dimensity 7200, Octa Core, 2.8 GHz Processor
# 4     Snapdragon 7s Gen 2, Octa Core, 2.4 GHz Processor
# ...                                                 ...
# 1015                           52 MB RAM, 52 MB inbuilt
# 1016                                            No Wifi
# 1017                                  1.2 MHz Processor
# 1018                     Single Core, 208 MHz Processor
# 1019                           32 MB RAM, 32 MB inbuilt
#
#                            ram                                  battery  \
# 0     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 44W Fast Charging
# 1     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 45W Fast Charging
# 2      4 GB RAM, 64 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 3     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 44W Fast Charging
# 4     8 GB RAM, 128 GB inbuilt  5100 mAh Battery with 67W Fast Charging
# ...                        ...                                      ...
# 1015          1800 mAh Battery         1.8 inches, 640 x 480 px Display
# 1016         1.2 MHz Processor                 32 MB RAM, 32 MB inbuilt
# 1017  32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
# 1018  32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
# 1019          1000 mAh Battery         1.8 inches, 128 x 160 px Display
#
#                                                 display  \
# 0     6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 1     6.7 inches, 1084 x 2412 px, 120 Hz Display wit...
# 2     6.71 inches, 720 x 1650 px, 90 Hz Display with...
# 3     6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# ...                                                 ...
# 1015                                0.03 MP Rear Camera
# 1016                                   1000 mAh Battery
# 1017                   1.8 inches, 320 x 480 px Display
# 1018                   1.8 inches, 120 x 240 px Display
# 1019                                     No Rear Camera
#
#                                                  camera  \
# 0         50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 1          50 MP + 50 MP Dual Rear & 32 MP Front Camera
# 2          8 MP + 0.08 MP Dual Rear & 5 MP Front Camera
# 3           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 4     200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015                   Memory Card (Hybrid), upto 32 GB
# 1016                   1.8 inches, 320 x 480 px Display
# 1017                                 0.3 MP Rear Camera
# 1018                                     No Rear Camera
# 1019                  Memory Card Supported, upto 32 GB
#
#                                    card                                 os
# 0       Memory Card (Hybrid), upto 1 TB                        Android v14
# 1                           Android v14                        No FM Radio
# 2      Memory Card Supported, upto 1 TB                        Android v14
# 3       Memory Card (Hybrid), upto 1 TB                        Android v14
# 4                           Android v13                        No FM Radio
# ...                                 ...                                ...
# 1015                          Bluetooth                                NaN
# 1016                 0.3 MP Rear Camera  Memory Card Supported, upto 16 GB
# 1017  Memory Card Supported, upto 16 GB                          Bluetooth
# 1018  Memory Card Supported, upto 32 GB                          Bluetooth
# 1019                       Symbian v9.3                          Bluetooth
#
# [1020 rows x 11 columns]
